# %% [markdown]
# ![IMG_4373.JPEG](attachment:IMG_4373.JPEG)

# %% [markdown]
# **Импортируем библиотеки для дальнейшей работы с ними**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeRegressor, plot_tree
from sklearn.linear_model import LinearRegression
from sklearn.neighbors import KNeighborsClassifier
import matplotlib.pyplot as plt
import seaborn as sns
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from sklearn.model_selection import train_test_split
#       3 from sklearn.linear_model import LogisticRegression
#       4 from sklearn.tree import DecisionTreeRegressor, plot_tree
#
# ModuleNotFoundError: No module named 'sklearn'

# %% [markdown]
# **Загружаем наш датасет**

# %%
data = pd.read_csv("C:\PycharmProjects\projectdata\StudentsPerformance.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 data = pd.read_csv("C:\PycharmProjects\projectdata\StudentsPerformance.csv")
#
# ...

# %% [markdown]
# **Выводим датасет**

# %%
data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 data
#
# NameError: name 'data' is not defined

# %% [markdown]
# **Изменяем значения теста на int чтобы не было ошибки синтаксиса**

# %%
data["test preparation course"]=data["test preparation course"].map({"completed": 1, "none": 0})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 data["test preparation course"]=data["test preparation course"].map({"completed": 1, "none": 0})
#
# NameError: name 'data' is not defined

# %% [markdown]
# **Вычисляем среднюю оценку по матеше, письму и чтению**

# %%
data['average score'] = (data['math score'] + data['reading score'] + data['writing score']) / 3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 data['average score'] = (data['math score'] + data['reading score'] + data['writing score']) / 3
#
# NameError: name 'data' is not defined

# %% [markdown]
# **Разделение данных на (X) и (y)**

# %%
X = data[['test preparation course']]
y = data['average score']
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 X = data[['test preparation course']]
#       2 y = data['average score']
#
# NameError: name 'data' is not defined

# %% [markdown]
# **Создаем и обучаем модели дерева решений**

# %%
model = DecisionTreeRegressor()
model.fit(X, y)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 model = DecisionTreeRegressor()
#       2 model.fit(X, y)
#
# NameError: name 'DecisionTreeRegressor' is not defined

# %% [markdown]
# **Визуализируем модель дерева решений**

# %%
plt.figure(figsize=(10, 6))
plot_tree(model, filled=True, feature_names=['Проходил курс (1 - Да, 0 - Нет)'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 plt.figure(figsize=(10, 6))
#       2 plot_tree(model, filled=True, feature_names=['Проходил курс (1 - Да, 0 - Нет)'])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
/Users/karinashalya/Desktop/Снимок экрана 2023-10-10 в 23.57.29.png
# Out:
#   Cell In[11], line 1
#     Users/karinashalya/Desktop/Снимок(экрана, 2023-10-10, в, 23.57.29.png)
#                                                              ^
# SyntaxError: invalid syntax. Perhaps you forgot a comma?

# %% [markdown]
# **Снова загружаем наш датасет**

# %%
data = pd.read_csv("C:\PycharmProjects\projectdata\StudentsPerformance.csv")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 data = pd.read_csv("C:\PycharmProjects\projectdata\StudentsPerformance.csv")
#
# ...

# %% [markdown]
# **Подсчитаем количество мальчиков и девочек**

# %%
gender_counts = data['gender'].value_counts()

# %% [markdown]
# **Создаем круговую диаграмму**

# %%
lt.pie(gender_counts, labels=gender_counts.index, autopct='%1.1f%%', startangle=90, colors=['lightblue', 'lightpink'])

# %% [markdown]
# **Настраиваем подписи для диаграммы**

# %%
plt.title('Распределение студентов по полу')

# %% [markdown]
# **Отображаем диаграмму**

# %%
plt.show()

# %% [markdown]
# **Группируем данные по полу и типу обеда, а затем считаем количество записей в каждой группе**

# %%
meal_counts = data.groupby(['gender', 'lunch']).size().unstack()

# %% [markdown]
# **Создаем столбчатую диаграмму**

# %%
meal_counts.plot(kind='bar', stacked=True)

# %% [markdown]
# **Настраиваем подписи для графика**

# %%
plt.title('Количество бесплатных обедов у мальчиков и девочек')
plt.xlabel('Пол')
plt.ylabel('Количество студентов')

# %% [markdown]
# **Отображаем график**

# %%
plt.show()

# %% [markdown]
# **Снова загружаем наш датасет**

# %%
data = pd.read_csv("C:\PycharmProjects\projectdata\StudentsPerformance.csv")

# %% [markdown]
# Устанавливаем int-вые значения

# %%
data["gender"]=data["gender"].map({"female": 0, "male":1})

# %% [markdown]
# Устанавливаем int-вые значения 2.0

# %%
data["test preparation course"]=data["test preparation course"].map({"completed": 1, "none": 0})

# %% [markdown]
# Устанавливаем int-вые значения 2.1

# %%
data["lunch"]=data["lunch"].map({"standard": 1, "free/reduced": 0})

# %% [markdown]
# **Убираем не нужные нам столбцы**

# %%
data.drop(["race/ethnicity", "parental level of education"], axis=1, inplace=True)

# %% [markdown]
# **Выводим датасет чтобы проверить удалились ли столбцы**

# %%
data

# %% [markdown]
# **Выводим хитмап чтобы посмотреть зависимости**

# %%
hm = sns.heatmap(data.corr(),
                 cbar=True,
                 annot=True)

# %% [markdown]
# **Так как на хитмапе не все понятно, поэтому выводим линейные графики этих зависимостей**

# %%
g = sns.PairGrid(data)
g.map_diag(sns.histplot)
g.map_offdiag(sns.scatterplot)

# %% [markdown]
# **Cчитаем среднее значении за экзамены**

# %%
data['average score'] = (data['math score'] + data['reading score'] + data['writing score']) / 3

# %% [markdown]
# **Разделяем данные на (X) и (y)**

# %%
X = data[['math score']]
y = data['average score']

# %% [markdown]
# **Тренеруем модель**

# %%
eg = LinearRegression()
reg.fit(X, y)

# %% [markdown]
# **Выводим результат тренировки на график**

# %%
pred = reg.predict(X)
plt.figure(figsize=(12, 8))
plt.scatter(data['math score'], data['average score'])
plt.plot(data['math score'], pred, c='red', linewidth=2)
plt.xlabel("math score")
plt.ylabel("average score")
plt.show()

# %% [markdown]
# **Загружаем опять наш датасет**

# %%
data

# %% [markdown]
# **Избавимся от стринговых значений превратив их в int-овые**

# %%
data["gender"]=data["gender"].map({"female": 0, "male":1})

# %%
data["lunch"]=data["lunch"].map({"standard": 1, "free/reduced": 0})

# %%
data["test preparation course"]=data["test preparation course"].map({"completed": 1, "none": 0})

# %% [markdown]
# **Опять считаем**

# %%
data['average score'] = (data['math score'] + data['reading score'] + data['writing score']) / 3

# %% [markdown]
# Снова раздели данные на x и y

# %%
X = data[['average score']]
y = data['gender']

# %% [markdown]
# Опять начинаем тренировать модель

# %%
logreg = LogisticRegression(max_iter = 1000) 
logreg.fit(X, y)
logreg.score(X, y)

# %%
print(logreg.predict_proba([[0], [1], [1], [0]])*100)

# %% [markdown]
# Загружаем наш датасет

# %%
data = pd.read_csv("C:\PycharmProjects\projectdata\StudentsPerformance.csv")

# %%
data["lunch"]=data["lunch"].map({"standard": 1, "free/reduced": 0})
data["gender"]=data["gender"].map({"female": 0, "male":1})

# %% [markdown]
# Делим данные

# %%
X = data[['lunch']]
y = data['gender']

# %% [markdown]
# Опять тренируем

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=17)

# %% [markdown]
# Тренируется

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train, y_train)

# %% [markdown]
# Выводим значения

# %%
knn.score(X, y)

# %%
print(knn.predict([[0], [1], [0], [1], [1]]))
